# %%
import math as m
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = 'comparison_all_algorithms.csv'
data2 = 'comparison_growth_rate.csv'
data3 = 'comparison_speedup.csv'
data4 = 'comparison_summary.csv'

df1 = pd.read_csv(data1)
df2 = pd.read_csv(data2)
df3 = pd.read_csv(data3)
df4 = pd.read_csv(data4)

# %%
df1
# Out:
#          Algorithm       Data Type  Input Size (n)  Comparisons  \
# 0    Linear Search          Sorted            1000          901
# 1    Binary Search          Sorted            1000            8
# 2    Linear Search          Sorted            5000         4501
# 3    Binary Search          Sorted            5000            9
# 4    Linear Search          Sorted           10000         9001
# ..             ...             ...             ...          ...
# 63  Insertion Sort  Reverse Sorted            5000     12497500
# 64      Merge Sort  Reverse Sorted            5000        32004
# 65     Bubble Sort  Reverse Sorted           10000     49995000
# 66  Insertion Sort  Reverse Sorted           10000     49995000
# 67      Merge Sort  Reverse Sorted           10000        69008
#
#     Time (seconds) Complexity Class                             Notes
# 0         0.000099             O(n)            Target at 90% position
# ...
